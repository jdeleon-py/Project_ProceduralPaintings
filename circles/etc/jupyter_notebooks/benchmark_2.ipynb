# %%
'''Benchmark #2'''

'''
add onto benchmark #1 by now introducing a few shape objects 
into the system

the canvas algorithm will go, and then the shape algorithm will go

test to see how much the evolution is affected by the order of 
shapes placed onto the canvas

shape objects can vary in size, location, and RGBA color
'''

import math
import random
import imgcompare
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw

# %%
class Hyperparameters:
    '''
    '''
    HYPERPARAMETER = 0

# %%
class Canvas:
    '''
    - handles only the background color of the painting
    '''
    def __init__(self) -> None:
        self.color = self.define_color()
    
    def __str__(self) -> str:
        return "Color: {}".format(self.color)
    
    def define_color(self) -> list:
        R = random.randint(0, 255)
        G = random.randint(0, 255)
        B = random.randint(0, 255)
        return [R, G, B]


if __name__ == "__main__":
    canvases = [Canvas() for _ in range(0, 10)]
    for canvas in canvases: print("{}".format(canvas))
# Out:
# Color: [130, 1, 88]
# Color: [207, 123, 211]
# Color: [195, 19, 123]
# Color: [13, 78, 85]
# Color: [71, 209, 220]
# Color: [124, 53, 58]
# Color: [177, 231, 25]
# Color: [93, 54, 148]
# Color: [207, 234, 81]
# Color: [105, 17, 111]

# %%
class Shape:
    '''
    - circles
    '''
    def __init__(self, width: int, height: int, factor: float) -> None:
        self.width = width
        self.height = height
        self.factor = factor
        self.color = self.define_color()
        self.radius = int(0.5 * random.gammavariate(self.factor, 0.1 * self.get_hypotenuse()))
        self.center = [random.randint(0, self.width - 1), random.randint(0, self.height - 1)]
    
    def __str__(self) -> str:
        '''
        - reads out key specs fo the shape -> (color, center coordinate, radius)
        '''
        return "Color: {0}; Radius: {1}; Center: {2}".format(self.color, self.radius, self.center)
    
    def crossover(self):
        pass
    
    def define_color(self) -> list:
        R = random.randint(0, 255)
        G = random.randint(0, 255)
        B = random.randint(0, 255)
        A = random.randint(0, 255)
        return [R, G, B, A]
    
    def define_drawing_coordinates(self) -> list:
        '''
        - the drawing tool requires the shape's boundary coordinates in order to draw
        - the shape's center coordinate and radius are used to compute the boundary points
        '''
        x0 = self.center[0] - self.radius # 180 deg position
        x1 = self.center[0] + self.radius #   0 deg position
        y0 = self.center[1] - self.radius # 270 deg position
        y1 = self.center[1] + self.radius #  90 deg position
        return [x0, y0, x1, y1]
    
    def draw_circle(self, drawing_tool: object) -> None:
        '''
        - using the PIL library, this function draws an ellipse with symmetrical 
          coordinates, thus drawing a circle
        - the drawing tool is defined in the Painting object
        '''
        drawing_tool.ellipse(tuple(self.define_drawing_coordinates()), tuple(self.color))
    
    def get_hypotenuse(self) -> int:
        return int(math.sqrt((self.width) ** 2 + (self.height) ** 2))

if __name__ == "__main__":
    WIDTH, HEIGHT, FACTOR = 400, 400, 1
    shapes = [Shape(WIDTH, HEIGHT, FACTOR) for _ in range(0, 10)]
    for shape in shapes: print("{}".format(shape))
# Out:
# Color: [25, 226, 249, 87]; Radius: 47; Center: [377, 203]
# Color: [220, 4, 120, 222]; Radius: 6; Center: [44, 388]
# Color: [74, 234, 130, 80]; Radius: 16; Center: [234, 277]
# Color: [234, 222, 174, 154]; Radius: 31; Center: [360, 377]
# Color: [186, 129, 202, 66]; Radius: 13; Center: [362, 155]
# Color: [33, 207, 11, 143]; Radius: 8; Center: [22, 256]
# Color: [31, 112, 236, 56]; Radius: 7; Center: [237, 190]
# Color: [137, 213, 155, 230]; Radius: 2; Center: [212, 265]
# Color: [48, 169, 78, 18]; Radius: 53; Center: [199, 347]
# Color: [75, 36, 216, 222]; Radius: 53; Center: [36, 274]

# %%
class Painting:
    '''
    '''
    def __init__(self, width: int, height: int, size: int) -> None:
        self.width = width
        self.height = height
        self.size = size
        self.canvas_genotype = Canvas()
        self.shape_genotype = [Shape(width = self.width,
                                     height = self.height,
                                     factor = 2) for _ in range(0, self.size)]

        self.overall_fitness = 0
        self.r_fitness = 0
        self.g_fitness = 0
        self.b_fitness = 0
        self.create_painting()
    
    def create_painting(self) -> None:
        self.sort_genotype(mode = '5')
        self.phenotype = Image.new(mode = 'RGB',
                                   size = (self.width, self.height),
                                   color = tuple(self.canvas_genotype.color))
        self.draw = ImageDraw.Draw(self.phenotype, 'RGBA')
        for shape in self.shape_genotype: shape.draw_circle(self.draw)
    
    def show_painting(self) -> None:
        self.phenotype.show()
    
    def save_painting(self, painting_id: int) -> None:
        '''
        - saves the populated image as a png file
        '''
        self.phenotype.save('../lib/benchmark2_test/test_painting{}.png'.format(str(painting_id)))
    
    def crossover(self, parent_canvas_gen: object, parent_shape_gen: object, mutation_rate: float) -> object:
        child = Painting(width = self.width, height = self.height, size = self.size)
        # CANVAS CROSSOVER
        child.canvas_genotype.color[0] = int(0.5 * (self.canvas_genotype.color[0] + parent_canvas_gen.color[0]))
        child.canvas_genotype.color[1] = int(0.5 * (self.canvas_genotype.color[1] + parent_canvas_gen.color[1]))
        child.canvas_genotype.color[2] = int(0.5 * (self.canvas_genotype.color[2] + parent_canvas_gen.color[2]))
        # SHAPE CROSSOVER
        if random.choice([0, 1]) == 0:
            '''
            - the first half of parent 1 is combined with the second half of parent 2
            '''
            parent1_traits = self.shape_genotype[: int(len(self.shape_genotype) / 2)]
            parent2_traits = parent_shape_gen[int(len(parent_shape_gen) / 2) :]
            child.shape_genotype = parent1_traits + parent2_traits
        else:
            '''
            - the second half of parent 1 is combined with the first half of parent 2
            '''
            parent1_traits = self.shape_genotype[int(len(self.shape_genotype) / 2) :]
            parent2_traits = parent_shape_gen[: int(len(parent_shape_gen) / 2)]
            child.shape_genotype = parent1_traits + parent2_traits
        child.canvas_mutate(mutation_rate = mutation_rate)
        child.shape_mutate(mutation_rate = mutation_rate, mode = '5')
        return child
    
    def canvas_mutate(self, mutation_rate: float) -> None:
        for index in range(0, len(self.canvas_genotype.color)):
            if random.randint(1, int(1 / mutation_rate)) == 1:
                self.canvas_genotype.color[index] = self.canvas_genotype.color[index] + random.randint(-30, 30)
    
    def shape_mutate(self, mutation_rate: float, mode: str) -> None:
        '''
        | specs:
        | - design in modes to compare methods
        | - "for" = for shape in shapes...
        | - "if" = if a shape is to be mutated or not
        | - "choose" = choose one of the mutation types
        | - extensive documentation!!!
        '''
        mutation_types = ['shape', 'gene']
        weights = [0.99, 0.01]
        mutation = random.choices(mutation_types, weights = weights, k = 1)[0]
        if mutation == 'shape':
            if mode == '1':
                ''' for -> if -> choose'''
                for shape in self.shape_genotype:
                    if random.randint(1, int(1 / mutation_rate)) == 1:
                        shape_mut_types = ['radius', 'shift', 'R', 'G', 'B', 'A']
                        shape_weights = [0.10, 0.10, 0.20, 0.20, 0.20, 0.20]
                        shape_mutation = random.choices(shape_mut_types, 
                                                        weights = shape_weights, 
                                                        k = 1)[0]
                        self.choose_mutation(obj = shape, mut_type = shape_mutation)
            elif mode == '2':
                ''' for -> choose -> if'''
                for shape in self.shape_genotype:
                    shape_mut_types = ['radius', 'shift', 'R', 'G', 'B', 'A']
                    shape_weights = [0.10, 0.10, 0.20, 0.20, 0.20, 0.20]
                    shape_mutation = random.choices(shape_mut_types, 
                                                    weights = shape_weights, 
                                                    k = 1)[0]
                    if random.randint(1, int(1 / mutation_rate)) == 1:
                        shape.choose_mutation(obj = shape, mut_type = shape_mutation)
            elif mode == '3':
                ''' choose -> for -> if'''
                shape_mut_types = ['radius', 'shift', 'R', 'G', 'B', 'A']
                shape_weights = [0.10, 0.10, 0.20, 0.20, 0.20, 0.20]
                shape_mutation = random.choices(shape_mut_types, 
                                                weights = shape_weights, 
                                                k = 1)[0]
                for shape in self.shape_genotype:
                    if random.randint(1, int(1 / mutation_rate)) == 1:
                        shape.choose_mutation(obj = shape, mut_type = shape_mutation)
            elif mode == '4':
                ''' choose -> if -> for'''
                shape_mut_types = ['radius', 'shift', 'R', 'G', 'B', 'A']
                shape_weights = [0.10, 0.10, 0.20, 0.20, 0.20, 0.20]
                shape_mutation = random.choices(shape_mut_types, 
                                                weights = shape_weights, 
                                                k = 1)[0]
                if random.randint(1, int(1 / mutation_rate)) == 1:
                    for shape in self.shape_genotype:
                        shape.choose_mutation(obj = shape, mut_type = shape_mutation)
            elif mode == '5':
                '''if -> choose -> for'''
                if random.randint(1, int(1 / mutation_rate)) == 1:
                    shape_mut_types = ['radius', 'shift', 'R', 'G', 'B', 'A']
                    shape_weights = [0.10, 0.10, 0.20, 0.20, 0.20, 0.20]
                    shape_mutation = random.choices(shape_mut_types, 
                                                    weights = shape_weights, 
                                                    k = 1)[0]
                    for shape in self.shape_genotype:
                        self.choose_mutation(obj = shape, mut_type = shape_mutation)
            elif mode == '6':
                ''' if -> for -> choose'''
                if random.randint(1, int(1 / mutation_rate)) == 1:
                    for shape in self.shape_genotype:
                        shape_mut_types = ['radius', 'shift', 'R', 'G', 'B', 'A']
                        shape_weights = [0.10, 0.10, 0.20, 0.20, 0.20, 0.20]
                        shape_mutation = random.choices(shape_mut_types, 
                                                        weights = shape_weights, 
                                                        k = 1)[0]
                        self.choose_mutation(obj = shape, mut_type = shape_mutation)
            else:
                '''choose a default means of mutation'''
                pass
        else:
            gene_mutation_types = ['add', 'subtract']
            gene_weights = [0.85, 0.15]
            gene_mutation = random.choices(gene_mutation_types, weights = gene_weights, k = 1)[0]
            if gene_mutation == 'add':
                self.shape_genotype.append(self.create_new_gene(factor = 0.5))
            else:
                if self.shape_genotype: self.shape_genotype.pop(0)
    
    def choose_mutation(self, obj: object, mut_type: str) -> None:
        if mut_type == 'radius':
            self.mutate_radius(shape = obj)
        elif mut_type == 'shift':
            self.mutate_coordinates(shape = obj)
        elif mut_type == 'R':
            self.mutate_color_R(shape = obj)
        elif mut_type == 'G':
            self.mutate_color_G(shape = obj)
        elif mut_type == 'B':
            self.mutate_color_B(shape = obj)
        elif mut_type == 'A':
            self.mutate_color_A(shape = obj)
        else:
            pass

    def mutate_coordinates(self, shape: object) -> None:
        x_shift = random.randint(-5, 5)
        y_shift = random.randint(-5, 5)
        shape.center = [shape.center[0] + x_shift, shape.center[1] + y_shift]
        shape.center[0] = min(max(shape.center[0], 0), shape.width - 1)
        shape.center[1] = min(max(shape.center[1], 0), shape.height - 1)
    
    def mutate_color_R(self, shape: object) -> None:
        R_shift = random.randint(-10, 10)
        shape.color[0] = shape.color[0] + R_shift
        shape.color[0] = min(max(shape.color[0], 0), 255)
        
    def mutate_color_G(self, shape: object) -> None:
        G_shift = random.randint(-10, 10)
        shape.color[1] = shape.color[1] + G_shift
        shape.color[1] = min(max(shape.color[1], 0), 255)
        
    def mutate_color_B(self, shape: object) -> None:
        B_shift = random.randint(-10, 10)
        shape.color[2] = shape.color[2] + B_shift
        shape.color[2] = min(max(shape.color[2], 0), 255)
        
    def mutate_color_A(self, shape: object) -> None:
        A_shift = random.randint(-10, 10)
        shape.color[3] = shape.color[3] + A_shift
        shape.color[3] = min(max(shape.color[3], 0), 255)
    
    def mutate_radius(self, shape: object) -> None:
        shift = random.randint(-1, 1)
        shape.radius = shape.radius + shift
    
    def sort_genotype(self, mode: int) -> None:
        '''
        | specs:
        | - design in modes to compare methods
        | - extensive documentation!!!
        | - mode #1: larger, more opaque shapes are drawn first
        | - mode #2: smaller, less opaque shapes are drawn first
        | - mode #3: smaller, more opaque shapes are drawn first
        | - mode #4: larger, less opaque shapes are drawn first
        |
        | - mode #5: larger shapes are drawn first
        | - mode #6: smaller shapes are drawn first
        | - mode #7: more opaque shapes are drawn first
        | - mode #8: less opaque shapes are drawn first
        '''
        if mode == '1':
            sort_func = lambda shape: (0.5 * shape.radius) + (0.5 * shape.color[-1])
            self.shape_genotype.sort(reverse = True, key = sort_func)
        elif mode == '2':
            func = lambda shape: (0.5 * shape.radius) + (0.5 * shape.color[-1])
            self.shape_genotype.sort(reverse = False, key = func)
        elif mode == '3':
            max_rad = max([shape.radius for shape in self.shape_genotype])
            sort_func = lambda shape: (0.5 * (max_rad - shape.radius)) + (0.5 * shape.color[-1])
            self.shape_genotype.sort(reverse = True, key = sort_func)
        elif mode == '4':
            max_opac = max([shape.color[-1] for shape in self.shape_genotype])
            sort_func = lambda shape: (0.5 * (max_opac - shape.color[-1])) + (0.5 * shape.radius)
            self.shape_genotype.sort(reverse = True, key = sort_func)
        elif mode == '5':
            self.shape_genotype.sort(reverse = True, key = lambda shape: shape.radius)
        elif mode == '6':
            self.shape_genotype.sort(reverse = False, key = lambda shape: shape.radius)
        elif mode == '7':
            self.shape_genotype.sort(reverse = True, key = lambda shape: shape.color[-1])
        elif mode == '8':
            self.shape_genotype.sort(reverse = False, key = lambda shape: shape.color[-1])
        else:
            '''opt for a random placement of shapes onto the canvas'''
            pass
    
    def create_new_gene(self, factor):
        '''
        - probablistically, an entire new gene will be generated
        '''
        return Shape(width = self.width, height = self.height, factor = factor)


if __name__ == "__main__":
    painting = Painting(width = 500, height = 500, size = 500)
    painting.show_painting()
    print('{}'.format(painting.canvas_genotype))
    for shape in painting.shape_genotype: print('{}'.format(shape))
# Out:
# Color: [219, 174, 154]
# Color: [7, 3, 253, 146]; Radius: 327; Center: [166, 97]
# Color: [121, 38, 230, 125]; Radius: 292; Center: [11, 421]
# Color: [82, 93, 14, 180]; Radius: 265; Center: [42, 331]
# Color: [217, 202, 213, 40]; Radius: 245; Center: [491, 330]
# Color: [49, 144, 59, 234]; Radius: 236; Center: [232, 293]
# Color: [105, 125, 251, 187]; Radius: 228; Center: [381, 54]
# Color: [164, 155, 208, 64]; Radius: 220; Center: [140, 374]
# Color: [239, 16, 222, 29]; Radius: 211; Center: [387, 25]
# Color: [187, 125, 41, 29]; Radius: 205; Center: [94, 454]
# Color: [56, 192, 8, 141]; Radius: 203; Center: [223, 117]
# Color: [242, 222, 254, 221]; Radius: 202; Center: [204, 308]
# Color: [185, 39, 225, 187]; Radius: 202; Center: [340, 312]
# Color: [168, 215, 243, 128]; Radius: 190; Center: [128, 70]
# Color: [118, 166, 15, 16]; Radius: 187; Center: [347, 85]
# Color: [84, 18, 65, 253]; Radius: 181; Center: [117, 379]
# Color: [14, 34, 205, 81]; Radius: 178; Center: [413, 194]
# Color: [99, 141, 174, 164]; Radius: 176; Center: [332, 147]
# Color: [202, 106, 212, 219]; Radius: 171; Center: [62, 390]
# Color: [187, 172, 231, 26]; Radius: 171; Center: [54, 21]
# Color: [152, 240, 130, 144]; Radius: 168; Center: [437, 253]
# Color: [122, 30, 64, 84]; Radius: 161; Center: [439, 415]
# Color: [206, 79, 224, 47]; Radius: 161; Center: [1, 13]
# Color: [76, 125, 162, 33]; Radius: 160; Center: [427, 475]
# Color: [230, 70, 155, 215]; Radius: 160; Center: [305, 155]
# Color: [118, 91, 54, 110]; Radius: 159; Center: [113, 19]
# Color: [235, 102, 251, 90]; Radius: 159; Center: [352, 132]
# Color: [91, 248, 8, 81]; Radius: 159; Center: [445, 238]
# Color: [110, 161, 6, 216]; Radius: 159; Center: [333, 262]
# Color: [212, 169, 107, 68]; Radius: 157; Center: [44, 210]
# Color: [38, 73, 55, 94]; Radius: 157; Center: [105, 287]
# Color: [98, 58, 105, 135]; Radius: 156; Center: [274, 352]
# Color: [153, 221, 122, 184]; Radius: 155; Center: [58, 370]
# Color: [41, 202, 108, 202]; Radius: 151; Center: [29, 133]
# Color: [135, 107, 155, 89]; Radius: 151; Center: [223, 59]
# Color: [184, 113, 49, 222]; Radius: 150; Center: [203, 369]
# Color: [153, 21, 241, 86]; Radius: 149; Center: [480, 421]
# Color: [41, 135, 55, 230]; Radius: 148; Center: [462, 116]
# Color: [150, 167, 51, 209]; Radius: 147; Center: [28, 460]
# Color: [93, 188, 165, 226]; Radius: 147; Center: [114, 439]
# Color: [58, 67, 196, 77]; Radius: 145; Center: [208, 203]
# Color: [24, 55, 40, 30]; Radius: 143; Center: [208, 79]
# Color: [82, 8, 207, 71]; Radius: 142; Center: [263, 453]
# Color: [105, 70, 213, 234]; Radius: 141; Center: [228, 80]
# Color: [177, 101, 220, 76]; Radius: 140; Center: [235, 338]
# Color: [83, 28, 72, 231]; Radius: 139; Center: [330, 9]
# Color: [68, 191, 190, 95]; Radius: 138; Center: [327, 55]
# Color: [243, 153, 168, 123]; Radius: 138; Center: [76, 441]
# Color: [143, 238, 112, 167]; Radius: 137; Center: [10, 324]
# Color: [216, 38, 0, 233]; Radius: 135; Center: [25, 89]
# Color: [209, 238, 120, 89]; Radius: 133; Center: [207, 433]
# Color: [101, 114, 103, 238]; Radius: 130; Center: [188, 252]
# Color: [170, 179, 6, 218]; Radius: 130; Center: [430, 468]
# Color: [149, 255, 40, 66]; Radius: 130; Center: [230, 479]
# Color: [44, 79, 106, 190]; Radius: 130; Center: [197, 367]
# Color: [172, 214, 243, 247]; Radius: 129; Center: [48, 95]
# Color: [185, 119, 219, 48]; Radius: 129; Center: [427, 138]
# Color: [30, 72, 24, 176]; Radius: 126; Center: [240, 223]
# Color: [170, 112, 114, 100]; Radius: 124; Center: [86, 216]
# Color: [106, 237, 42, 181]; Radius: 124; Center: [357, 7]
# Color: [50, 202, 158, 82]; Radius: 123; Center: [326, 121]
# Color: [112, 87, 189, 30]; Radius: 122; Center: [429, 56]
# Color: [239, 247, 78, 61]; Radius: 122; Center: [145, 309]
# Color: [145, 86, 79, 59]; Radius: 119; Center: [171, 139]
# Color: [65, 189, 169, 112]; Radius: 119; Center: [39, 309]
# Color: [242, 69, 213, 156]; Radius: 118; Center: [171, 342]
# Color: [39, 21, 63, 233]; Radius: 118; Center: [169, 305]
# Color: [22, 135, 225, 81]; Radius: 116; Center: [55, 330]
# Color: [223, 129, 29, 183]; Radius: 116; Center: [391, 334]
# Color: [8, 200, 237, 225]; Radius: 115; Center: [363, 476]
# Color: [83, 16, 99, 170]; Radius: 115; Center: [436, 336]
# Color: [231, 91, 110, 94]; Radius: 114; Center: [93, 242]
# Color: [29, 8, 233, 50]; Radius: 114; Center: [482, 27]
# Color: [135, 62, 164, 145]; Radius: 114; Center: [90, 98]
# Color: [182, 214, 44, 30]; Radius: 113; Center: [42, 336]
# Color: [151, 111, 210, 143]; Radius: 113; Center: [166, 38]
# Color: [156, 208, 94, 21]; Radius: 112; Center: [227, 305]
# Color: [28, 125, 82, 201]; Radius: 112; Center: [325, 316]
# Color: [14, 26, 168, 214]; Radius: 112; Center: [173, 360]
# Color: [223, 196, 39, 168]; Radius: 111; Center: [305, 455]
# Color: [66, 170, 211, 91]; Radius: 107; Center: [209, 228]
# Color: [189, 152, 128, 237]; Radius: 107; Center: [258, 154]
# Color: [154, 176, 215, 115]; Radius: 107; Center: [236, 158]
# Color: [198, 2, 226, 60]; Radius: 106; Center: [128, 212]
# Color: [209, 5, 121, 16]; Radius: 106; Center: [477, 350]
# Color: [2, 156, 222, 153]; Radius: 106; Center: [123, 96]
# Color: [8, 48, 198, 15]; Radius: 106; Center: [433, 172]
# Color: [126, 142, 151, 202]; Radius: 106; Center: [225, 147]
# Color: [32, 97, 49, 137]; Radius: 105; Center: [283, 146]
# Color: [51, 135, 45, 147]; Radius: 104; Center: [270, 83]
# Color: [188, 7, 236, 250]; Radius: 104; Center: [271, 473]
# Color: [80, 42, 124, 14]; Radius: 104; Center: [240, 428]
# Color: [91, 20, 16, 30]; Radius: 104; Center: [140, 57]
# Color: [166, 230, 185, 175]; Radius: 103; Center: [1, 372]
# Color: [187, 253, 123, 146]; Radius: 103; Center: [447, 6]
# Color: [54, 136, 141, 106]; Radius: 103; Center: [262, 47]
# Color: [23, 160, 53, 80]; Radius: 102; Center: [76, 476]
# Color: [208, 117, 204, 130]; Radius: 102; Center: [356, 191]
# Color: [105, 161, 133, 101]; Radius: 102; Center: [269, 117]
# Color: [112, 97, 28, 25]; Radius: 102; Center: [443, 319]
# Color: [74, 126, 110, 59]; Radius: 101; Center: [63, 365]
# Color: [160, 89, 64, 164]; Radius: 100; Center: [419, 291]
# Color: [235, 95, 162, 96]; Radius: 100; Center: [353, 299]
# Color: [248, 197, 139, 32]; Radius: 100; Center: [273, 61]
# Color: [140, 58, 174, 6]; Radius: 99; Center: [477, 118]
# Color: [200, 254, 222, 97]; Radius: 99; Center: [479, 176]
# Color: [131, 241, 115, 91]; Radius: 99; Center: [123, 351]
# Color: [56, 13, 144, 93]; Radius: 98; Center: [330, 403]
# Color: [93, 119, 219, 255]; Radius: 97; Center: [233, 16]
# Color: [246, 207, 115, 72]; Radius: 97; Center: [243, 302]
# Color: [145, 190, 231, 154]; Radius: 97; Center: [137, 498]
# Color: [8, 237, 1, 173]; Radius: 97; Center: [287, 77]
# Color: [111, 202, 106, 141]; Radius: 96; Center: [220, 427]
# Color: [31, 160, 247, 98]; Radius: 96; Center: [356, 304]
# Color: [88, 116, 215, 121]; Radius: 95; Center: [16, 363]
# Color: [64, 9, 170, 174]; Radius: 95; Center: [201, 410]
# Color: [30, 175, 20, 15]; Radius: 95; Center: [428, 234]
# Color: [133, 122, 97, 195]; Radius: 95; Center: [404, 456]
# Color: [49, 126, 134, 53]; Radius: 95; Center: [389, 345]
# Color: [92, 211, 85, 111]; Radius: 94; Center: [1, 373]
# Color: [60, 63, 92, 140]; Radius: 94; Center: [44, 246]
# Color: [82, 177, 179, 252]; Radius: 93; Center: [142, 59]
# Color: [86, 56, 26, 218]; Radius: 92; Center: [59, 50]
# Color: [224, 141, 215, 243]; Radius: 92; Center: [284, 22]
# Color: [48, 87, 214, 205]; Radius: 92; Center: [427, 66]
# Color: [4, 138, 251, 32]; Radius: 92; Center: [124, 342]
# Color: [212, 6, 239, 60]; Radius: 92; Center: [4, 399]
# Color: [192, 122, 67, 11]; Radius: 92; Center: [114, 464]
# Color: [197, 125, 74, 82]; Radius: 92; Center: [148, 234]
# Color: [126, 230, 129, 138]; Radius: 91; Center: [298, 400]
# Color: [79, 30, 74, 240]; Radius: 91; Center: [377, 381]
# Color: [186, 45, 254, 34]; Radius: 91; Center: [300, 323]
# Color: [76, 180, 11, 134]; Radius: 91; Center: [70, 325]
# Color: [224, 33, 47, 173]; Radius: 91; Center: [431, 329]
# Color: [230, 121, 131, 180]; Radius: 90; Center: [186, 157]
# Color: [217, 108, 161, 137]; Radius: 90; Center: [418, 229]
# Color: [177, 250, 185, 208]; Radius: 89; Center: [250, 298]
# Color: [126, 69, 95, 187]; Radius: 89; Center: [73, 361]
# Color: [128, 192, 188, 9]; Radius: 89; Center: [217, 461]
# Color: [184, 64, 187, 229]; Radius: 89; Center: [421, 241]
# Color: [78, 67, 60, 3]; Radius: 88; Center: [150, 344]
# Color: [15, 214, 10, 47]; Radius: 87; Center: [136, 10]
# Color: [81, 197, 147, 195]; Radius: 85; Center: [94, 415]
# Color: [233, 40, 1, 169]; Radius: 85; Center: [247, 436]
# Color: [177, 121, 113, 61]; Radius: 84; Center: [286, 286]
# Color: [247, 106, 189, 149]; Radius: 84; Center: [65, 139]
# Color: [18, 161, 243, 128]; Radius: 82; Center: [472, 483]
# Color: [11, 178, 143, 157]; Radius: 82; Center: [356, 268]
# Color: [14, 86, 82, 101]; Radius: 82; Center: [281, 256]
# Color: [126, 191, 149, 172]; Radius: 82; Center: [74, 216]
# Color: [55, 170, 221, 146]; Radius: 82; Center: [50, 309]
# Color: [179, 249, 197, 234]; Radius: 82; Center: [266, 371]
# Color: [4, 197, 1, 170]; Radius: 82; Center: [443, 361]
# Color: [128, 188, 20, 129]; Radius: 81; Center: [88, 1]
# Color: [154, 34, 190, 223]; Radius: 81; Center: [238, 376]
# Color: [79, 78, 241, 47]; Radius: 81; Center: [44, 267]
# Color: [67, 21, 141, 126]; Radius: 81; Center: [19, 279]
# Color: [161, 190, 143, 28]; Radius: 81; Center: [289, 360]
# Color: [23, 156, 175, 1]; Radius: 80; Center: [45, 228]
# Color: [27, 7, 215, 186]; Radius: 79; Center: [370, 345]
# Color: [126, 248, 238, 18]; Radius: 79; Center: [103, 179]
# Color: [131, 238, 85, 38]; Radius: 79; Center: [77, 10]
# Color: [33, 106, 223, 232]; Radius: 79; Center: [113, 427]
# Color: [61, 71, 125, 186]; Radius: 79; Center: [17, 86]
# Color: [8, 3, 238, 12]; Radius: 78; Center: [339, 203]
# Color: [82, 43, 28, 249]; Radius: 78; Center: [445, 62]
# Color: [163, 20, 14, 174]; Radius: 77; Center: [38, 296]
# Color: [11, 76, 47, 138]; Radius: 77; Center: [148, 40]
# Color: [233, 238, 17, 200]; Radius: 77; Center: [349, 373]
# Color: [77, 1, 207, 105]; Radius: 77; Center: [214, 453]
# Color: [159, 109, 207, 208]; Radius: 77; Center: [312, 88]
# Color: [254, 55, 34, 0]; Radius: 77; Center: [120, 460]
# Color: [159, 167, 255, 149]; Radius: 77; Center: [419, 445]
# Color: [194, 157, 78, 98]; Radius: 76; Center: [53, 79]
# Color: [40, 231, 49, 12]; Radius: 76; Center: [411, 256]
# Color: [231, 199, 135, 215]; Radius: 76; Center: [33, 134]
# Color: [100, 91, 143, 200]; Radius: 76; Center: [189, 16]
# Color: [21, 250, 138, 26]; Radius: 75; Center: [416, 35]
# Color: [131, 108, 112, 193]; Radius: 75; Center: [31, 364]
# Color: [111, 198, 52, 193]; Radius: 75; Center: [200, 166]
# Color: [12, 21, 204, 26]; Radius: 75; Center: [317, 463]
# Color: [133, 21, 159, 91]; Radius: 75; Center: [251, 391]
# Color: [53, 39, 232, 159]; Radius: 75; Center: [167, 260]
# Color: [55, 58, 120, 81]; Radius: 74; Center: [469, 349]
# Color: [18, 67, 141, 1]; Radius: 73; Center: [495, 203]
# Color: [47, 241, 205, 254]; Radius: 73; Center: [373, 380]
# Color: [189, 194, 74, 1]; Radius: 72; Center: [277, 438]
# Color: [206, 12, 239, 117]; Radius: 72; Center: [221, 450]
# Color: [82, 47, 43, 151]; Radius: 72; Center: [306, 45]
# Color: [223, 25, 113, 232]; Radius: 72; Center: [284, 46]
# Color: [236, 177, 206, 169]; Radius: 72; Center: [320, 315]
# Color: [192, 48, 200, 237]; Radius: 71; Center: [278, 176]
# Color: [235, 137, 190, 60]; Radius: 71; Center: [359, 317]
# Color: [79, 228, 169, 17]; Radius: 71; Center: [474, 317]
# Color: [16, 9, 197, 228]; Radius: 71; Center: [104, 243]
# Color: [55, 4, 46, 89]; Radius: 70; Center: [368, 33]
# Color: [80, 231, 250, 236]; Radius: 70; Center: [302, 214]
# Color: [0, 126, 80, 41]; Radius: 70; Center: [161, 29]
# Color: [33, 252, 162, 93]; Radius: 70; Center: [426, 113]
# Color: [40, 197, 219, 239]; Radius: 69; Center: [443, 156]
# Color: [224, 4, 255, 8]; Radius: 69; Center: [220, 55]
# Color: [218, 48, 169, 76]; Radius: 69; Center: [19, 212]
# Color: [244, 23, 47, 44]; Radius: 69; Center: [82, 278]
# Color: [250, 220, 165, 145]; Radius: 69; Center: [177, 355]
# Color: [56, 235, 215, 139]; Radius: 68; Center: [463, 115]
# Color: [0, 63, 240, 4]; Radius: 68; Center: [125, 429]
# Color: [104, 210, 31, 106]; Radius: 67; Center: [78, 240]
# Color: [65, 173, 163, 52]; Radius: 67; Center: [142, 192]
# Color: [136, 129, 74, 227]; Radius: 66; Center: [346, 149]
# Color: [200, 64, 73, 34]; Radius: 65; Center: [433, 497]
# Color: [207, 138, 20, 211]; Radius: 65; Center: [228, 465]
# Color: [111, 105, 174, 252]; Radius: 65; Center: [300, 76]
# Color: [175, 221, 32, 16]; Radius: 65; Center: [410, 84]
# Color: [24, 32, 79, 246]; Radius: 65; Center: [157, 301]
# Color: [125, 72, 192, 199]; Radius: 64; Center: [488, 245]
# Color: [249, 176, 53, 166]; Radius: 64; Center: [0, 366]
# Color: [148, 17, 178, 84]; Radius: 64; Center: [434, 315]
# Color: [63, 143, 144, 159]; Radius: 64; Center: [48, 72]
# Color: [252, 51, 89, 240]; Radius: 64; Center: [334, 51]
# Color: [136, 231, 115, 167]; Radius: 64; Center: [240, 153]
# Color: [55, 18, 104, 46]; Radius: 63; Center: [200, 328]
# Color: [131, 62, 95, 119]; Radius: 63; Center: [197, 180]
# Color: [94, 147, 174, 199]; Radius: 63; Center: [40, 201]
# Color: [224, 86, 165, 209]; Radius: 63; Center: [369, 157]
# Color: [161, 12, 150, 242]; Radius: 63; Center: [94, 356]
# Color: [79, 8, 204, 91]; Radius: 63; Center: [55, 475]
# Color: [21, 64, 193, 188]; Radius: 62; Center: [414, 410]
# Color: [222, 120, 144, 136]; Radius: 62; Center: [103, 27]
# Color: [220, 76, 172, 48]; Radius: 62; Center: [315, 496]
# Color: [195, 42, 80, 18]; Radius: 62; Center: [486, 237]
# Color: [156, 15, 21, 216]; Radius: 61; Center: [425, 368]
# Color: [197, 8, 84, 177]; Radius: 61; Center: [362, 495]
# Color: [80, 34, 139, 198]; Radius: 61; Center: [475, 8]
# Color: [60, 245, 125, 240]; Radius: 60; Center: [181, 333]
# Color: [146, 223, 97, 163]; Radius: 60; Center: [387, 130]
# Color: [231, 43, 56, 42]; Radius: 60; Center: [144, 60]
# Color: [240, 208, 57, 235]; Radius: 60; Center: [266, 349]
# Color: [201, 9, 138, 183]; Radius: 59; Center: [112, 296]
# Color: [231, 158, 81, 209]; Radius: 58; Center: [133, 498]
# Color: [192, 20, 57, 244]; Radius: 58; Center: [318, 456]
# Color: [189, 156, 11, 113]; Radius: 58; Center: [454, 69]
# Color: [150, 223, 167, 208]; Radius: 57; Center: [483, 9]
# Color: [113, 236, 69, 244]; Radius: 57; Center: [182, 439]
# Color: [22, 180, 155, 50]; Radius: 57; Center: [414, 336]
# Color: [217, 162, 254, 177]; Radius: 57; Center: [90, 410]
# Color: [58, 8, 209, 135]; Radius: 57; Center: [435, 190]
# Color: [20, 221, 144, 75]; Radius: 57; Center: [417, 477]
# Color: [168, 79, 227, 30]; Radius: 56; Center: [376, 215]
# Color: [36, 78, 137, 186]; Radius: 56; Center: [42, 297]
# Color: [48, 48, 212, 239]; Radius: 56; Center: [52, 233]
# Color: [19, 195, 179, 149]; Radius: 56; Center: [13, 276]
# Color: [14, 59, 160, 214]; Radius: 55; Center: [156, 490]
# Color: [46, 99, 119, 200]; Radius: 55; Center: [19, 385]
# Color: [17, 230, 13, 241]; Radius: 55; Center: [373, 218]
# Color: [246, 71, 15, 113]; Radius: 55; Center: [425, 403]
# Color: [231, 137, 252, 241]; Radius: 55; Center: [48, 75]
# Color: [188, 252, 87, 195]; Radius: 54; Center: [96, 388]
# Color: [233, 254, 135, 174]; Radius: 54; Center: [219, 293]
# Color: [104, 180, 147, 3]; Radius: 54; Center: [332, 13]
# Color: [213, 73, 48, 198]; Radius: 54; Center: [49, 227]
# Color: [239, 202, 59, 97]; Radius: 54; Center: [333, 60]
# Color: [142, 12, 245, 209]; Radius: 54; Center: [157, 45]
# Color: [110, 17, 143, 99]; Radius: 54; Center: [415, 188]
# Color: [53, 233, 217, 4]; Radius: 54; Center: [408, 207]
# Color: [156, 113, 201, 217]; Radius: 53; Center: [452, 466]
# Color: [250, 232, 167, 251]; Radius: 53; Center: [10, 254]
# Color: [212, 41, 139, 86]; Radius: 53; Center: [256, 296]
# Color: [250, 90, 214, 124]; Radius: 53; Center: [88, 177]
# Color: [179, 226, 177, 125]; Radius: 52; Center: [325, 401]
# Color: [50, 204, 20, 132]; Radius: 52; Center: [486, 331]
# Color: [248, 236, 249, 232]; Radius: 52; Center: [176, 59]
# Color: [236, 106, 64, 212]; Radius: 52; Center: [219, 151]
# Color: [63, 216, 200, 193]; Radius: 51; Center: [162, 60]
# Color: [132, 46, 78, 131]; Radius: 51; Center: [381, 373]
# Color: [188, 20, 51, 121]; Radius: 51; Center: [356, 277]
# Color: [167, 76, 108, 183]; Radius: 51; Center: [117, 404]
# Color: [240, 15, 196, 13]; Radius: 50; Center: [76, 382]
# Color: [5, 206, 83, 152]; Radius: 50; Center: [144, 439]
# Color: [200, 214, 4, 110]; Radius: 50; Center: [353, 81]
# Color: [39, 81, 35, 202]; Radius: 50; Center: [339, 348]
# Color: [103, 66, 150, 197]; Radius: 50; Center: [192, 365]
# Color: [163, 61, 218, 164]; Radius: 49; Center: [143, 98]
# Color: [198, 28, 85, 151]; Radius: 49; Center: [285, 53]
# Color: [84, 141, 143, 169]; Radius: 49; Center: [119, 112]
# Color: [220, 20, 230, 163]; Radius: 49; Center: [122, 55]
# Color: [100, 170, 249, 37]; Radius: 49; Center: [403, 458]
# Color: [232, 187, 215, 134]; Radius: 49; Center: [160, 417]
# Color: [48, 156, 155, 163]; Radius: 48; Center: [156, 346]
# Color: [27, 137, 38, 141]; Radius: 48; Center: [248, 232]
# Color: [95, 167, 101, 16]; Radius: 48; Center: [153, 198]
# Color: [57, 247, 183, 103]; Radius: 48; Center: [301, 360]
# Color: [33, 78, 183, 74]; Radius: 47; Center: [412, 370]
# Color: [177, 82, 245, 178]; Radius: 47; Center: [1, 207]
# Color: [144, 105, 28, 143]; Radius: 47; Center: [99, 122]
# Color: [89, 171, 253, 156]; Radius: 47; Center: [294, 198]
# Color: [121, 228, 147, 159]; Radius: 46; Center: [488, 369]
# Color: [197, 239, 107, 8]; Radius: 46; Center: [467, 300]
# Color: [226, 151, 155, 63]; Radius: 46; Center: [288, 354]
# Color: [173, 158, 15, 208]; Radius: 46; Center: [247, 188]
# Color: [133, 105, 210, 245]; Radius: 46; Center: [128, 50]
# Color: [11, 72, 81, 43]; Radius: 46; Center: [423, 20]
# Color: [87, 101, 156, 240]; Radius: 45; Center: [244, 273]
# Color: [12, 209, 112, 12]; Radius: 45; Center: [25, 172]
# Color: [198, 34, 168, 128]; Radius: 45; Center: [123, 376]
# Color: [69, 58, 243, 132]; Radius: 45; Center: [183, 173]
# Color: [85, 131, 178, 99]; Radius: 44; Center: [95, 475]
# Color: [9, 176, 20, 190]; Radius: 44; Center: [133, 364]
# Color: [41, 255, 122, 102]; Radius: 44; Center: [251, 250]
# Color: [223, 226, 76, 189]; Radius: 44; Center: [45, 493]
# Color: [212, 155, 242, 234]; Radius: 44; Center: [164, 177]
# Color: [33, 158, 245, 30]; Radius: 43; Center: [455, 498]
# Color: [248, 5, 64, 25]; Radius: 42; Center: [142, 34]
# Color: [254, 106, 97, 14]; Radius: 42; Center: [463, 445]
# Color: [90, 237, 20, 8]; Radius: 42; Center: [498, 398]
# Color: [210, 101, 27, 168]; Radius: 41; Center: [184, 111]
# Color: [90, 4, 42, 218]; Radius: 41; Center: [199, 486]
# Color: [32, 110, 70, 239]; Radius: 40; Center: [395, 260]
# Color: [198, 91, 171, 118]; Radius: 40; Center: [184, 422]
# Color: [148, 50, 136, 85]; Radius: 40; Center: [199, 408]
# Color: [97, 212, 162, 20]; Radius: 40; Center: [365, 35]
# Color: [30, 213, 18, 139]; Radius: 40; Center: [73, 418]
# Color: [207, 9, 131, 136]; Radius: 40; Center: [87, 58]
# Color: [114, 79, 157, 3]; Radius: 39; Center: [25, 90]
# Color: [169, 210, 42, 153]; Radius: 39; Center: [351, 59]
# Color: [66, 86, 25, 198]; Radius: 39; Center: [120, 24]
# Color: [215, 255, 13, 83]; Radius: 39; Center: [160, 218]
# Color: [169, 206, 37, 160]; Radius: 39; Center: [310, 193]
# Color: [238, 255, 189, 210]; Radius: 38; Center: [455, 288]
# Color: [177, 244, 184, 130]; Radius: 38; Center: [239, 102]
# Color: [188, 56, 123, 181]; Radius: 38; Center: [453, 122]
# Color: [173, 237, 166, 54]; Radius: 38; Center: [193, 252]
# Color: [174, 9, 229, 2]; Radius: 38; Center: [362, 446]
# Color: [107, 225, 87, 66]; Radius: 38; Center: [127, 99]
# Color: [110, 174, 106, 37]; Radius: 37; Center: [424, 206]
# Color: [46, 243, 221, 205]; Radius: 37; Center: [396, 43]
# Color: [135, 19, 23, 142]; Radius: 37; Center: [148, 341]
# Color: [240, 245, 64, 88]; Radius: 36; Center: [369, 180]
# Color: [109, 74, 173, 41]; Radius: 36; Center: [230, 190]
# Color: [110, 97, 248, 18]; Radius: 36; Center: [464, 16]
# Color: [17, 233, 36, 249]; Radius: 36; Center: [427, 223]
# Color: [141, 60, 106, 196]; Radius: 36; Center: [213, 397]
# Color: [19, 191, 99, 197]; Radius: 36; Center: [382, 1]
# Color: [217, 153, 174, 147]; Radius: 36; Center: [222, 213]
# Color: [98, 125, 41, 44]; Radius: 36; Center: [315, 86]
# Color: [103, 40, 7, 168]; Radius: 36; Center: [416, 255]
# Color: [161, 148, 160, 222]; Radius: 36; Center: [363, 498]
# Color: [8, 104, 30, 218]; Radius: 35; Center: [295, 450]
# Color: [117, 124, 138, 12]; Radius: 35; Center: [424, 139]
# Color: [125, 20, 198, 144]; Radius: 35; Center: [212, 204]
# Color: [19, 211, 28, 16]; Radius: 35; Center: [210, 436]
# Color: [202, 253, 142, 51]; Radius: 35; Center: [453, 463]
# Color: [32, 105, 93, 150]; Radius: 35; Center: [74, 460]
# Color: [185, 125, 193, 120]; Radius: 34; Center: [435, 389]
# Color: [154, 123, 210, 236]; Radius: 34; Center: [496, 258]
# Color: [108, 226, 33, 237]; Radius: 34; Center: [377, 26]
# Color: [115, 106, 181, 150]; Radius: 34; Center: [463, 70]
# Color: [242, 40, 84, 253]; Radius: 33; Center: [68, 95]
# Color: [160, 187, 189, 86]; Radius: 33; Center: [106, 25]
# Color: [150, 115, 250, 159]; Radius: 33; Center: [498, 357]
# Color: [214, 129, 191, 199]; Radius: 33; Center: [492, 237]
# Color: [106, 40, 146, 140]; Radius: 33; Center: [242, 288]
# Color: [78, 39, 22, 184]; Radius: 33; Center: [250, 44]
# Color: [15, 114, 195, 108]; Radius: 33; Center: [7, 75]
# Color: [47, 131, 91, 177]; Radius: 33; Center: [207, 487]
# Color: [230, 150, 96, 13]; Radius: 32; Center: [408, 306]
# Color: [182, 82, 226, 185]; Radius: 32; Center: [496, 19]
# Color: [246, 186, 232, 124]; Radius: 31; Center: [450, 396]
# Color: [166, 181, 17, 204]; Radius: 31; Center: [323, 394]
# Color: [14, 26, 162, 26]; Radius: 31; Center: [186, 262]
# Color: [14, 87, 139, 70]; Radius: 31; Center: [386, 242]
# Color: [219, 247, 198, 133]; Radius: 31; Center: [388, 251]
# Color: [197, 30, 41, 126]; Radius: 31; Center: [413, 216]
# Color: [121, 81, 221, 238]; Radius: 31; Center: [323, 374]
# Color: [179, 16, 18, 120]; Radius: 30; Center: [212, 77]
# Color: [188, 25, 41, 6]; Radius: 30; Center: [113, 65]
# Color: [77, 30, 26, 22]; Radius: 30; Center: [308, 462]
# Color: [116, 182, 163, 153]; Radius: 30; Center: [176, 233]
# Color: [16, 80, 137, 19]; Radius: 29; Center: [159, 466]
# Color: [171, 129, 91, 236]; Radius: 29; Center: [175, 46]
# Color: [78, 201, 188, 38]; Radius: 29; Center: [47, 461]
# Color: [83, 103, 188, 135]; Radius: 29; Center: [410, 385]
# Color: [149, 192, 0, 187]; Radius: 29; Center: [462, 370]
# Color: [100, 242, 80, 195]; Radius: 28; Center: [181, 85]
# Color: [50, 127, 10, 66]; Radius: 28; Center: [358, 488]
# Color: [10, 228, 73, 104]; Radius: 28; Center: [279, 383]
# Color: [75, 54, 252, 172]; Radius: 28; Center: [416, 157]
# Color: [137, 35, 162, 206]; Radius: 28; Center: [438, 149]
# Color: [143, 233, 253, 10]; Radius: 28; Center: [216, 302]
# Color: [155, 149, 117, 254]; Radius: 28; Center: [271, 421]
# Color: [237, 21, 163, 90]; Radius: 28; Center: [146, 423]
# Color: [20, 204, 13, 82]; Radius: 28; Center: [347, 41]
# Color: [191, 36, 56, 3]; Radius: 27; Center: [255, 252]
# Color: [25, 56, 10, 88]; Radius: 27; Center: [349, 248]
# Color: [219, 42, 197, 28]; Radius: 27; Center: [423, 116]
# Color: [217, 21, 63, 255]; Radius: 27; Center: [344, 268]
# Color: [220, 143, 47, 210]; Radius: 27; Center: [189, 207]
# Color: [220, 221, 155, 177]; Radius: 26; Center: [444, 199]
# Color: [197, 162, 250, 208]; Radius: 26; Center: [35, 322]
# Color: [190, 161, 108, 89]; Radius: 26; Center: [409, 85]
# Color: [103, 71, 106, 250]; Radius: 26; Center: [73, 201]
# Color: [177, 165, 3, 19]; Radius: 26; Center: [104, 270]
# Color: [126, 181, 218, 6]; Radius: 26; Center: [330, 275]
# Color: [159, 152, 232, 17]; Radius: 26; Center: [98, 377]
# Color: [227, 199, 163, 236]; Radius: 26; Center: [496, 123]
# Color: [51, 24, 168, 91]; Radius: 26; Center: [262, 32]
# Color: [26, 107, 59, 219]; Radius: 25; Center: [454, 326]
# Color: [147, 1, 25, 230]; Radius: 25; Center: [190, 296]
# Color: [52, 150, 112, 23]; Radius: 25; Center: [0, 42]
# Color: [115, 28, 86, 215]; Radius: 25; Center: [484, 187]
# Color: [232, 250, 244, 18]; Radius: 25; Center: [397, 264]
# Color: [144, 109, 94, 154]; Radius: 24; Center: [260, 247]
# Color: [251, 95, 243, 206]; Radius: 24; Center: [204, 328]
# Color: [14, 9, 225, 210]; Radius: 24; Center: [39, 470]
# Color: [73, 160, 26, 50]; Radius: 24; Center: [232, 47]
# Color: [42, 18, 152, 245]; Radius: 24; Center: [286, 4]
# Color: [248, 180, 130, 34]; Radius: 23; Center: [142, 359]
# Color: [57, 61, 77, 28]; Radius: 23; Center: [403, 240]
# Color: [210, 180, 16, 194]; Radius: 23; Center: [484, 243]
# Color: [220, 170, 63, 203]; Radius: 23; Center: [265, 286]
# Color: [42, 111, 97, 137]; Radius: 23; Center: [27, 290]
# Color: [219, 15, 231, 55]; Radius: 23; Center: [448, 278]
# Color: [3, 113, 166, 58]; Radius: 23; Center: [269, 170]
# Color: [11, 45, 166, 23]; Radius: 22; Center: [162, 168]
# Color: [169, 35, 177, 183]; Radius: 22; Center: [137, 63]
# Color: [96, 86, 157, 221]; Radius: 21; Center: [267, 266]
# Color: [53, 107, 15, 227]; Radius: 21; Center: [257, 228]
# Color: [230, 139, 11, 161]; Radius: 21; Center: [360, 31]
# Color: [60, 247, 142, 6]; Radius: 21; Center: [359, 180]
# Color: [144, 58, 101, 239]; Radius: 21; Center: [248, 479]
# Color: [249, 166, 97, 72]; Radius: 20; Center: [292, 27]
# Color: [203, 221, 66, 118]; Radius: 20; Center: [156, 104]
# Color: [243, 188, 92, 184]; Radius: 20; Center: [456, 41]
# Color: [248, 199, 48, 107]; Radius: 20; Center: [234, 265]
# Color: [45, 70, 208, 196]; Radius: 20; Center: [210, 199]
# Color: [71, 247, 230, 101]; Radius: 20; Center: [166, 91]
# Color: [80, 74, 44, 119]; Radius: 20; Center: [115, 1]
# Color: [227, 189, 182, 195]; Radius: 19; Center: [307, 498]
# Color: [58, 3, 102, 11]; Radius: 19; Center: [87, 479]
# Color: [214, 163, 252, 115]; Radius: 19; Center: [147, 175]
# Color: [164, 122, 58, 1]; Radius: 19; Center: [432, 329]
# Color: [235, 45, 43, 226]; Radius: 19; Center: [195, 290]
# Color: [21, 146, 114, 126]; Radius: 19; Center: [134, 43]
# Color: [111, 190, 136, 97]; Radius: 18; Center: [193, 85]
# Color: [234, 243, 39, 48]; Radius: 18; Center: [465, 446]
# Color: [80, 47, 220, 178]; Radius: 18; Center: [380, 164]
# Color: [151, 138, 145, 218]; Radius: 17; Center: [195, 213]
# Color: [139, 222, 154, 82]; Radius: 17; Center: [42, 331]
# Color: [80, 77, 251, 23]; Radius: 17; Center: [52, 275]
# Color: [153, 202, 12, 116]; Radius: 17; Center: [336, 398]
# Color: [212, 52, 66, 70]; Radius: 16; Center: [181, 53]
# Color: [7, 45, 201, 91]; Radius: 16; Center: [71, 147]
# Color: [19, 239, 195, 52]; Radius: 16; Center: [288, 255]
# Color: [150, 198, 108, 38]; Radius: 16; Center: [244, 452]
# Color: [81, 200, 163, 194]; Radius: 16; Center: [84, 170]
# Color: [1, 66, 111, 160]; Radius: 16; Center: [113, 485]
# Color: [108, 14, 156, 215]; Radius: 16; Center: [246, 457]
# Color: [82, 30, 179, 128]; Radius: 15; Center: [366, 86]
# Color: [205, 215, 80, 190]; Radius: 15; Center: [19, 452]
# Color: [185, 167, 135, 238]; Radius: 15; Center: [374, 160]
# Color: [251, 139, 180, 214]; Radius: 14; Center: [319, 102]
# Color: [107, 157, 104, 128]; Radius: 14; Center: [73, 132]
# Color: [215, 159, 212, 233]; Radius: 14; Center: [197, 220]
# Color: [53, 230, 61, 134]; Radius: 14; Center: [319, 309]
# Color: [232, 59, 37, 29]; Radius: 14; Center: [151, 419]
# Color: [142, 124, 169, 235]; Radius: 14; Center: [399, 5]
# Color: [187, 229, 243, 183]; Radius: 13; Center: [469, 470]
# Color: [142, 51, 252, 178]; Radius: 12; Center: [336, 205]
# Color: [227, 85, 232, 128]; Radius: 12; Center: [469, 11]
# Color: [131, 183, 238, 71]; Radius: 12; Center: [432, 235]
# Color: [98, 128, 246, 240]; Radius: 12; Center: [250, 165]
# Color: [222, 150, 92, 225]; Radius: 11; Center: [297, 488]
# Color: [150, 214, 12, 74]; Radius: 11; Center: [320, 222]
# Color: [75, 148, 57, 4]; Radius: 11; Center: [345, 379]
# Color: [212, 10, 55, 66]; Radius: 11; Center: [109, 140]
# Color: [4, 53, 131, 209]; Radius: 11; Center: [426, 202]
# Color: [60, 218, 76, 95]; Radius: 10; Center: [489, 274]
# Color: [1, 123, 89, 181]; Radius: 10; Center: [18, 232]
# Color: [250, 28, 58, 32]; Radius: 10; Center: [420, 157]
# Color: [244, 50, 38, 53]; Radius: 9; Center: [22, 249]
# Color: [223, 142, 10, 88]; Radius: 9; Center: [59, 304]
# Color: [255, 240, 186, 54]; Radius: 9; Center: [482, 237]
# Color: [202, 241, 224, 240]; Radius: 9; Center: [373, 387]
# Color: [40, 195, 169, 106]; Radius: 8; Center: [282, 460]
# Color: [232, 191, 16, 44]; Radius: 8; Center: [410, 243]
# Color: [113, 211, 48, 158]; Radius: 8; Center: [439, 241]
# Color: [64, 223, 169, 253]; Radius: 8; Center: [192, 194]
# Color: [251, 243, 89, 76]; Radius: 7; Center: [81, 14]
# Color: [220, 210, 241, 98]; Radius: 6; Center: [101, 20]
# Color: [118, 96, 88, 19]; Radius: 6; Center: [378, 104]
# Color: [255, 110, 64, 1]; Radius: 6; Center: [75, 400]
# Color: [3, 132, 203, 248]; Radius: 6; Center: [345, 332]
# Color: [45, 33, 13, 85]; Radius: 6; Center: [198, 189]
# Color: [163, 27, 117, 99]; Radius: 5; Center: [438, 497]
# Color: [59, 85, 90, 108]; Radius: 5; Center: [421, 143]
# Color: [47, 174, 242, 221]; Radius: 4; Center: [475, 283]
# Color: [215, 236, 80, 185]; Radius: 4; Center: [139, 222]
# Color: [113, 231, 205, 170]; Radius: 4; Center: [298, 489]
# Color: [29, 56, 152, 14]; Radius: 4; Center: [11, 128]
# Color: [168, 0, 225, 17]; Radius: 4; Center: [392, 224]
# Color: [28, 52, 164, 216]; Radius: 3; Center: [280, 436]
# Color: [130, 254, 90, 18]; Radius: 1; Center: [281, 49]

# %%
class Figure:
    '''
    '''
    def __init__(self, path: str) -> None:
        self.path = path
        self.image = Image.open(self.path)
        self.image = self.convert_image()
        self.width, self.height = self.image.size
        self.data = self.get_color_data(self.image)
        self.paint_data = []
    
    @staticmethod
    def get_color_data(image: object) -> list:
        return np.array(Image.Image.getdata(image))

    def calculate_overall_fitness(self, input_painting: object) -> float:
        '''
        - for each pixel, determine the mean error of the color map
        '''
        input_painting = input_painting.phenotype.convert('RGB')
        self.paint_data = self.get_color_data(input_painting)
        diff1_percent = imgcompare.image_diff_percent(self.image, input_painting)
        return 100 - diff1_percent
    
    def calculate_r_fitness(self) -> float:
        return 255 - np.mean(np.abs(self.paint_data[:, 0] - self.data[:, 0]))
    
    def calculate_g_fitness(self) -> float:
        return 255 - np.mean(np.abs(self.paint_data[:, 1] - self.data[:, 1]))
    
    def calculate_b_fitness(self) -> float:
        return 255 - np.mean(np.abs(self.paint_data[:, 2] - self.data[:, 2]))

    def convert_image(self) -> object:
        return self.image.convert('RGB')
        

if __name__ == "__main__":
    target = Figure('../lib/test_target1.png')
    test_p = Painting(target.width, target.height, 3)
    print('{}'.format(target.data.shape))
    print('{}'.format(target.data[:30]))
    print('Overall Fitness: {}'.format(target.calculate_overall_fitness(test_p)))
    print('R Fitness: {}'.format(target.calculate_r_fitness()))
    print('G Fitness: {}'.format(target.calculate_g_fitness()))
    print('B Fitness: {}'.format(target.calculate_b_fitness()))
# Out:
# (45000, 3)
# [[ 4  4 17]
#  [ 3  4 16]
#  [ 3  4 15]
#  [ 3  4 14]
#  [ 3  4 14]
#  [ 1  4 14]
#  [ 2  4 14]
#  [ 3  4 14]
#  [ 3  4 15]
#  [ 3  4 16]
#  [ 4  4 17]
#  [ 4  4 18]
#  [ 5  5 20]
#  [ 5  5 22]
#  [ 7  5 24]
#  [ 8  5 26]
#  [ 9  5 29]
#  [11  5 31]
#  [12  5 33]
#  [12  6 35]
#  [13  6 37]
#  [15  6 39]
#  [16  6 42]
#  [16  6 43]
#  [17  6 45]
#  [18  7 47]
#  [18  7 49]
#  [19  7 51]
#  [20  7 53]
#  [20  7 54]]
# Overall Fitness: 67.47547712418302
# R Fitness: 177.36913333333334
# G Fitness: 164.05793333333332
# B Fitness: 199.459

# %%
class Population:
    '''
    '''
    def __init__(self, max_population: int, mutation_rate: float, target_path: str, size: int) -> None:
        self.max_population = max_population
        self.mutation_rate = mutation_rate
        self.target_path = target_path
        self.size = size
        self.target = Figure(self.target_path)
        self.population = [Painting(width = self.target.width,
                                    height = self.target.height,
                                    size = self.size) for _ in range(0, self.max_population)]
        self.children = []
    
    def choose_parent(self) -> object:
        weights = [painting.fitness for painting in self.population]
        return random.choices(self.population, weights = weights, k = 1)[0]
    
    def evaluate_population(self) -> None:
        for painting in self.population:
            painting.create_painting()
            painting.overall_fitness = self.target.calculate_overall_fitness(painting)
            painting.r_fitness = self.target.calculate_r_fitness() + painting.overall_fitness
            painting.g_fitness = self.target.calculate_g_fitness() + painting.overall_fitness
            painting.b_fitness = self.target.calculate_b_fitness() + painting.overall_fitness
    
    def generate_next_generation(self) -> None:
        '''
        - sexual reproduction
        - organisms in the population must be unique in order to mate
        '''
        # separate pop into 3 arrays
        # perform 3 crossovers (r, g, b)
        # add up 3 children arrays into one children array
        self.children = []
        r_children = []
        g_children = []
        b_children = []
        self.scale_fitness()

        self.sort_fitness(mode = 'R')
        for _ in range(0, len(self.population), 6):
            parent1 = self.choose_parent()
            parent2 = self.choose_parent()
            while parent1 == parent2: parent2 = self.choose_parent()
            child = parent1.crossover(parent_canvas_gen = parent2.canvas_genotype, 
                                      parent_shape_gen = parent2.shape_genotype, 
                                      mutation_rate = self.mutation_rate)
            r_children.append(child)
        
        self.sort_fitness(mode = 'G')
        for _ in range(0, len(self.population), 6):
            parent1 = self.choose_parent()
            parent2 = self.choose_parent()
            while parent1 == parent2: parent2 = self.choose_parent()
            child = parent1.crossover(parent_canvas_gen = parent2.canvas_genotype,
                                      parent_shape_gen = parent2.shape_genotype, 
                                      mutation_rate = self.mutation_rate)
            g_children.append(child)
        
        self.sort_fitness(mode = 'B')
        for _ in range(0, len(self.population), 6):
            parent1 = self.choose_parent()
            parent2 = self.choose_parent()
            while parent1 == parent2: parent2 = self.choose_parent()
            child = parent1.crossover(parent_canvas_gen = parent2.canvas_genotype,
                                      parent_shape_gen = parent2.shape_genotype, 
                                      mutation_rate = self.mutation_rate)
            b_children.append(child)
        
        for index in r_children: self.children.append(index)
        for index in g_children: self.children.append(index)
        for index in b_children: self.children.append(index)

    def adjust_population(self) -> None:
        if random.choice([0, 1]) == 0:
            self.population = self.population[: int(len(self.population) / 2)] + self.children
        else:
            self.population = self.population[int(len(self.population) / 2) :] + self.children
    
    def sort_fitness(self, mode: str) -> None:
        if mode == 'R':
            self.population.sort(reverse = True, key = lambda painting: painting.r_fitness)
        elif mode == 'G':
            self.population.sort(reverse = True, key = lambda painting: painting.g_fitness)
        elif mode == 'B':
            self.population.sort(reverse = True, key = lambda painting: painting.b_fitness)
        else: # SORT OVERALL FITNESS
            self.population.sort(reverse = True, key = lambda painting: painting.overall_fitness)
    
    def scale_fitness(self) -> None:
        mode = 'x'
        if mode == 'R': pass
        elif mode == 'G': pass
        elif mode == 'B': pass
        else:
            self.sort_fitness(mode = 'X')
            for i in range(0, len(self.population)):
                self.population[i].fitness = int(10 * (self.max_population / ((i + 1) ** 0.5)))

if __name__ == "__main__":
    pop = Population(max_population = 100, 
                     mutation_rate = 0.05, 
                     target_path = '../lib/test_target0.png', 
                     size = 3)

    pop.evaluate_population()
    pop.sort_fitness(mode = 'R')
    print('Best R fitness: {}'.format(pop.population[0].r_fitness))

    pop.sort_fitness(mode = 'G')
    print('Best G fitness: {}'.format(pop.population[0].g_fitness))

    pop.sort_fitness(mode = 'B')
    print('Best B fitness: {}'.format(pop.population[0].b_fitness))

    pop.sort_fitness(mode = 'X')
    print('Best overall fitness: {}'.format(pop.population[0].overall_fitness))
# Out:
# Best R fitness: 240.0445350762527
# Best G fitness: 241.71226608569356
# Best B fitness: 228.33608830791576
# Best overall fitness: 66.96210312273058

# %%
class Evolution:
    '''
    '''
    def __init__(self) -> None:
        self.pop = Population(max_population = 60,
                              mutation_rate = 0.20,
                              target_path = '../lib/test_target0.png',
                              size = 5)
        self.generation = 1
        self.best_fitness = 0
    
    def evolve(self) -> None:
        count = 0
        # implement a canvas evolution
        # implement a shape evolution
        while count < 1000:
            self.pop.sort_fitness(mode = 'X')
            self.pop.population[0].save_painting(self.generation)
            self.pop.evaluate_population()
            self.save_best_painting()
            self.display_stats()
            self.pop.generate_next_generation()
            self.pop.adjust_population()
            self.generation += 1
            count += 1
    
    def save_best_painting(self) -> None:
        if self.pop.population[0].overall_fitness > self.best_fitness:
            self.pop.population[0].save_painting('_best')
            self.best_fitness = self.pop.population[0].overall_fitness
    
    def display_stats(self) -> None:
        print("--------------- STATS ---------------")
        print("Generation: {}".format(self.generation))
        print("Population Size: {}".format(len(self.pop.population)))
        print("Mean Fitness: {}".format(np.mean([i.overall_fitness for i in self.pop.population])))
        print("Std Fitness: {}".format(np.std([i.overall_fitness for i in self.pop.population])))
        print("Max Fitness: {}".format(max([i.overall_fitness for i in self.pop.population])))
        print("Min Fitness: {}".format(min([i.overall_fitness for i in self.pop.population])))
        print("-------------------------------------")

if __name__ == "__main__":
    evo = Evolution()
    evo.evolve()
# Out:
# --------------- STATS ---------------
# Generation: 1
# Population Size: 60
# Mean Fitness: 52.22962149600581
# Std Fitness: 5.245943642486015
# Max Fitness: 62.68047833454369
# Min Fitness: 37.69953231663036
# -------------------------------------
# --------------- STATS ---------------
# Generation: 2
# Population Size: 60
# Mean Fitness: 54.35738626644073
# Std Fitness: 4.67425939338579
# Max Fitness: 62.67438973614137
# Min Fitness: 41.94530718954248
# -------------------------------------
# --------------- STATS ---------------
# Generation: 3
# Population Size: 60
# Mean Fitness: 56.717323650447845
# Std Fitness: 4.714535304794299
# -------------------------------------
# --------------- STATS ---------------
# Generation: 158
# Population Size: 60
# Mean Fitness: 75.65011280561609
# Std Fitness: 0.5209941870471437
# Max Fitness: 76.3835894456548
# Min Fitness: 72.64019365771
# -------------------------------------
# --------------- STATS ---------------
# Generation: 159
# Population Size: 60
# Mean Fitness: 76.55888466069554
# Std Fitness: 0.3386152452619797
# Max Fitness: 77.11407407407407
# Min Fitness: 75.2965577342048
# -------------------------------------
# --------------- STATS ---------------
# Generation: 160
# Population Size: 60
# Mean Fitness: 76.62683205035101
# Std Fitness: 0.31732882815754626
# Max Fitness: 77.0004434761559
# Min Fitness: 75.70837472766884
# -------------------------------------
# --------------- STATS ---------------
# Generation: 161
# Population Size: 60
# Mean Fitness: 76.51914222544984
# Std Fitness: 0.2559571056478195
# Max Fitness: 76.94289615105302
# Min Fitness: 75.70949019607843
# -------------------------------------
# --------------- STATS ---------------
# Generation: 162
# Population Size: 60
# Mean Fitness: 76.7283669168079
# Std Fitness: 0.2950293513918563
# Max Fitness: 77.24387896393125
# Min Fitness: 75.93516339869281
# -------------------------------------
# --------------- STATS ---------------
# Generation: 163
# Population Size: 60
# Mean Fitness: 75.88221182925847
# Std Fitness: 0.3228527455718767
# Max Fitness: 76.31883030743161
# Min Fitness: 75.15832486080852
# -------------------------------------
# --------------- STATS ---------------
# Generation: 164
# Population Size: 60
# Mean Fitness: 74.60505227144355
# Std Fitness: 0.2370139130433885
# Max Fitness: 74.90644589687727
# Min Fitness: 73.93096877269426
# -------------------------------------
# --------------- STATS ---------------
# Generation: 165
# Population Size: 60
# Mean Fitness: 75.24412310175099
# Std Fitness: 0.30144715307632275
# Max Fitness: 75.48191140159767
# Min Fitness: 73.75915565238441
# -------------------------------------
# --------------- STATS ---------------
# Generation: 166
# Population Size: 60
# Mean Fitness: 74.76625540224319
# Std Fitness: 0.22860397459918025
# Max Fitness: 74.85308932461874
# Min Fitness: 74.0001045751634
# -------------------------------------
# --------------- STATS ---------------
# Generation: 167
# Population Size: 60
# Mean Fitness: 74.78122165738723
# Std Fitness: 0.2487702694208315
# Max Fitness: 74.90532268215928
# Min Fitness: 74.06090534979424
# -------------------------------------
# --------------- STATS ---------------
# Generation: 168
# Population Size: 60
# Mean Fitness: 75.47633535060115
# Std Fitness: 0.32657333813009
# Max Fitness: 75.69844396030017
# Min Fitness: 74.61104817235537
# -------------------------------------
# --------------- STATS ---------------
# Generation: 169
# Population Size: 60
# Mean Fitness: 73.53301857500202
# Std Fitness: 0.1696530687995999
# Max Fitness: 73.61535318324862
# Min Fitness: 72.72352069716776
# -------------------------------------
# --------------- STATS ---------------
# Generation: 170
# Population Size: 60
# Mean Fitness: 70.83728659727267
# Std Fitness: 0.18914691091992636
# Max Fitness: 70.96055386105058
# Min Fitness: 69.94308399903171
# -------------------------------------
# --------------- STATS ---------------
# Generation: 171
# Population Size: 60
# Mean Fitness: 71.48702060840797
# Std Fitness: 0.16633866986958507
# Max Fitness: 71.55873154199952
# Min Fitness: 70.5361181312031
# -------------------------------------
# --------------- STATS ---------------
# Generation: 172
# Population Size: 60
# Mean Fitness: 71.92913160655209
# Std Fitness: 0.0716559762443125
# Max Fitness: 71.96166351972889
# Min Fitness: 71.585007020092
# -------------------------------------
# --------------- STATS ---------------
# Generation: 173
# Population Size: 60
# Mean Fitness: 71.5072438957476
# Std Fitness: 0.09274034616426732
# Max Fitness: 71.53999322198015
# Min Fitness: 70.9281665456306
# -------------------------------------
# --------------- STATS ---------------
# Generation: 174
# Population Size: 60
# Mean Fitness: 71.25422428790445
# Std Fitness: 0.09212563416527479
# Max Fitness: 71.2888811425805
# Min Fitness: 70.68844153957879
# -------------------------------------
# --------------- STATS ---------------
# Generation: 175
# Population Size: 60
# Mean Fitness: 72.6626863552005
# Std Fitness: 0.2987292528287842
# Max Fitness: 72.78919389978213
# Min Fitness: 70.82139917695473
# -------------------------------------
# --------------- STATS ---------------
# Generation: 176
# Population Size: 60
# Mean Fitness: 73.75179201161946
# Std Fitness: 0.1614148192983336
# Max Fitness: 73.82228031953522
# Min Fitness: 72.99437811667877
# -------------------------------------
# --------------- STATS ---------------
# Generation: 177
# Population Size: 60
# Mean Fitness: 74.08045070604375
# Std Fitness: 0.15350224700024553
# Max Fitness: 74.16319535221496
# Min Fitness: 73.34270636649723
# -------------------------------------
# --------------- STATS ---------------
# Generation: 178
# Population Size: 60
# Mean Fitness: 72.64148264342774
# Std Fitness: 0.22762032801939
# Max Fitness: 72.75594674412974
# Min Fitness: 71.84549213265552
# -------------------------------------
# --------------- STATS ---------------
# Generation: 179
# Population Size: 60
# Mean Fitness: 71.83429871701767
# Std Fitness: 0.12986618025847982
# Max Fitness: 71.8884918905834
# Min Fitness: 71.3843001694505
# -------------------------------------
# --------------- STATS ---------------
# Generation: 180
# Population Size: 60
# Mean Fitness: 71.69993602840313
# Std Fitness: 0.16301846911055737
# Max Fitness: 71.76297845557977
# Min Fitness: 70.84756620672961
# -------------------------------------
# --------------- STATS ---------------
# Generation: 181
# Population Size: 60
# Mean Fitness: 71.98968630678608
# Std Fitness: 0.09158312907721862
# Max Fitness: 72.02158896151053
# Min Fitness: 71.63085741951102
# -------------------------------------
# --------------- STATS ---------------
# Generation: 182
# Population Size: 60
# Mean Fitness: 72.39766603727911
# Std Fitness: 0.04378250749228635
# Max Fitness: 72.41562817719681
# Min Fitness: 72.27314258048898
# -------------------------------------
# --------------- STATS ---------------
# Generation: 183
# Population Size: 60
# Mean Fitness: 71.12830739933834
# Std Fitness: 0.12540431243198177
# Max Fitness: 71.18279544904382
# Min Fitness: 70.42010941660615
# -------------------------------------
# --------------- STATS ---------------
# Generation: 184
# Population Size: 60
# Mean Fitness: 71.06354567901234
# Std Fitness: 0.17541182707724792
# Max Fitness: 71.15383974824498
# Min Fitness: 70.29461147421932
# -------------------------------------
# --------------- STATS ---------------
# Generation: 185
# Population Size: 60
# Mean Fitness: 71.00220898894538
# Std Fitness: 0.27136051843063475
# Max Fitness: 71.13826966836118
# Min Fitness: 69.37197966594044
# -------------------------------------
# --------------- STATS ---------------
# Generation: 186
# Population Size: 60
# Mean Fitness: 70.94385914629225
# Std Fitness: 0.26515937010237245
# Max Fitness: 71.10155991285403
# Min Fitness: 69.33960784313726
# -------------------------------------
# --------------- STATS ---------------
# Generation: 187
# Population Size: 60
# Mean Fitness: 68.01979724037763
# Std Fitness: 0.14894311719783654
# Max Fitness: 68.09919147906076
# Min Fitness: 67.19294311304769
# -------------------------------------
# --------------- STATS ---------------
# Generation: 188
# Population Size: 60
# Mean Fitness: 68.57379268942144
# Std Fitness: 0.1498785727384855
# Max Fitness: 68.66698039215686
# Min Fitness: 67.77491551682402
# -------------------------------------
# --------------- STATS ---------------
# Generation: 189
# Population Size: 60
# Mean Fitness: 68.37046823206649
# Std Fitness: 0.15700639827228494
# Max Fitness: 68.44978939724038
# Min Fitness: 67.55673299443234
# -------------------------------------
# --------------- STATS ---------------
# Generation: 190
# Population Size: 60
# Mean Fitness: 68.36038550794802
# Std Fitness: 0.12183663658661606
# Max Fitness: 68.44641200677802
# Min Fitness: 67.89735366739288
# -------------------------------------
# --------------- STATS ---------------
# Generation: 191
# Population Size: 60
# Mean Fitness: 68.31377467925442
# Std Fitness: 0.1231498821642008
# Max Fitness: 68.47865988864682
# Min Fitness: 67.8645480513193
# -------------------------------------
# --------------- STATS ---------------
# Generation: 192
# Population Size: 60
# Mean Fitness: 68.4393147099169
# Std Fitness: 0.10744683658957416
# Max Fitness: 68.58793706124425
# Min Fitness: 68.08318760590656
# -------------------------------------
# --------------- STATS ---------------
# Generation: 193
# Population Size: 60
# Mean Fitness: 68.23950320342128
# Std Fitness: 0.08026586826332958
# Max Fitness: 68.41654224158799
# Min Fitness: 68.05788041636407
# -------------------------------------
# --------------- STATS ---------------
# Generation: 194
# Population Size: 60
# Mean Fitness: 67.92203004922133
# Std Fitness: 0.12907688865391406
# Max Fitness: 68.06038247397724
# Min Fitness: 67.20825756475429
# -------------------------------------
# --------------- STATS ---------------
# Generation: 195
# Population Size: 60
# Mean Fitness: 68.02678854191883
# Std Fitness: 0.15210281413359467
# Max Fitness: 68.22508448317598
# Min Fitness: 67.28853255870249
# -------------------------------------
# --------------- STATS ---------------
# Generation: 196
# Population Size: 60
# Mean Fitness: 68.60048788832405
# Std Fitness: 0.16374211693633503
# Max Fitness: 68.75871992253691
# Min Fitness: 67.82154054708303
# -------------------------------------
# --------------- STATS ---------------
# Generation: 197
# Population Size: 60
# Mean Fitness: 68.44094504962479
# Std Fitness: 0.16435045836830622
# Max Fitness: 68.55965528927621
# Min Fitness: 67.66684676833697
# -------------------------------------
# --------------- STATS ---------------
# Generation: 198
# Population Size: 60
# Mean Fitness: 68.44959754700234
# Std Fitness: 0.08040612357882147
# Max Fitness: 68.52385959816026
# Min Fitness: 68.15327620430888
# -------------------------------------
# --------------- STATS ---------------
# Generation: 199
# Population Size: 60
# Mean Fitness: 68.10889192285967
# Std Fitness: 0.0979576247749265
# Max Fitness: 68.1997695473251
# Min Fitness: 67.77588380537401
# -------------------------------------
# --------------- STATS ---------------
# Generation: 200
# Population Size: 60
# Mean Fitness: 68.1219602033406
# Std Fitness: 0.08281758874785317
# Max Fitness: 68.1603795691116
# Min Fitness: 67.74687388041636
# -------------------------------------
# --------------- STATS ---------------
# Generation: 201
# Population Size: 60
# Mean Fitness: 67.91998657306544
# Std Fitness: 0.10571544409184107
# Max Fitness: 68.03422319051077
# Min Fitness: 67.43707576857904
# -------------------------------------
# --------------- STATS ---------------
# Generation: 202
# Population Size: 60
# Mean Fitness: 68.14159580408295
# Std Fitness: 0.18272162792021288
# Max Fitness: 68.29343790849674
# Min Fitness: 67.44114258048899
# -------------------------------------
# --------------- STATS ---------------
# ...
# Generation: 934
# Population Size: 60
# Mean Fitness: 64.58322872589365
# Std Fitness: 0.030225734048337602
# Max Fitness: 64.59045461147423
# Min Fitness: 64.38064584846285
# -------------------------------------
# --------------- STATS ---------------
# Generation: 935
# Population Size: 60
# Mean Fitness: 64.53812494149923
# Std Fitness: 0.034515349936099296
# Max Fitness: 64.54984846284192
# Min Fitness: 64.30966642459452
# -------------------------------------
# --------------- STATS ---------------
# Generation: 936
# Population Size: 60
# Mean Fitness: 64.65004915678205
# Std Fitness: 0.01606150208246859
# Max Fitness: 64.65389687726943
# Min Fitness: 64.54055289276204
# -------------------------------------
# --------------- STATS ---------------
# Generation: 937
# Population Size: 60
# Mean Fitness: 64.33742390058904
# Std Fitness: 0.05763274733601788
# Max Fitness: 64.36592011619462
# Min Fitness: 63.949757443718234
# -------------------------------------
# --------------- STATS ---------------
# Generation: 938
# Population Size: 60
# Mean Fitness: 64.74895815379651
# Std Fitness: 0.06891351239595082
# Max Fitness: 64.77409634471073
# Min Fitness: 64.34766981360445
# -------------------------------------
# --------------- STATS ---------------
# Generation: 939
# Population Size: 60
# Mean Fitness: 64.96361442749938
# Std Fitness: 0.008669957435588786
# Max Fitness: 64.96742870975551
# Min Fitness: 64.89758024691358
# -------------------------------------
# --------------- STATS ---------------
# Generation: 940
# Population Size: 60
# Mean Fitness: 65.45820279189869
# Std Fitness: 0.019277755296772205
# Max Fitness: 65.46540014524328
# Min Fitness: 65.32901863955459
# -------------------------------------
# --------------- STATS ---------------
# Generation: 941
# Population Size: 60
# Mean Fitness: 65.87836152666826
# Std Fitness: 0.060588289032444474
# Max Fitness: 66.30994141854273
# Min Fitness: 65.71994383926409
# -------------------------------------
# --------------- STATS ---------------
# Generation: 942
# Population Size: 60
# Mean Fitness: 66.18293862664407
# Std Fitness: 0.15571363932975993
# Max Fitness: 66.60957637375938
# Min Fitness: 65.35407794722828
# -------------------------------------
# --------------- STATS ---------------
# Generation: 943
# Population Size: 60
# Mean Fitness: 66.30881239409344
# Std Fitness: 0.2101539601988251
# Max Fitness: 66.71911692084241
# Min Fitness: 65.43255579762769
# -------------------------------------
# --------------- STATS ---------------
# Generation: 944
# Population Size: 60
# Mean Fitness: 66.24879296376986
# Std Fitness: 0.22119307077055228
# Max Fitness: 66.6160755265069
# Min Fitness: 65.35355894456549
# -------------------------------------
# --------------- STATS ---------------
# Generation: 945
# Population Size: 60
# Mean Fitness: 66.05733533446302
# Std Fitness: 0.22699101569962082
# Max Fitness: 66.75381263616558
# Min Fitness: 65.21979569111595
# -------------------------------------
# --------------- STATS ---------------
# Generation: 946
# Population Size: 60
# Mean Fitness: 66.34343426127653
# Std Fitness: 0.2569839100076206
# Max Fitness: 67.06312273057371
# Min Fitness: 65.4639748244977
# -------------------------------------
# --------------- STATS ---------------
# Generation: 947
# Population Size: 60
# Mean Fitness: 65.60641923666587
# Std Fitness: 0.2708033059496096
# Max Fitness: 66.39401984991528
# Min Fitness: 64.72491503267975
# -------------------------------------
# --------------- STATS ---------------
# Generation: 948
# Population Size: 60
# Mean Fitness: 65.89381941418543
# Std Fitness: 0.28864688990648646
# Max Fitness: 66.64250593076737
# Min Fitness: 65.0250612442508
# -------------------------------------
# --------------- STATS ---------------
# Generation: 949
# Population Size: 60
# Mean Fitness: 66.83264074880981
# Std Fitness: 0.26279599190578584
# Max Fitness: 67.41670297748729
# Min Fitness: 65.84612345679012
# -------------------------------------
# --------------- STATS ---------------
# Generation: 950
# Population Size: 60
# Mean Fitness: 66.08544772048738
# Std Fitness: 0.3333573473699535
# Max Fitness: 66.78846187363834
# Min Fitness: 65.05245993706124
# -------------------------------------
# --------------- STATS ---------------
# Generation: 951
# Population Size: 60
# Mean Fitness: 66.1294250625353
# Std Fitness: 0.4095507889727084
# Max Fitness: 66.7599864439603
# Min Fitness: 65.01044396030017
# -------------------------------------
# --------------- STATS ---------------
# Generation: 952
# Population Size: 60
# Mean Fitness: 65.98178933268781
# Std Fitness: 0.36253740047740934
# Max Fitness: 66.71786976519002
# Min Fitness: 65.00513773904623
# -------------------------------------
# --------------- STATS ---------------
# Generation: 953
# Population Size: 60
# Mean Fitness: 65.86349390785121
# Std Fitness: 0.31043992546060606
# Max Fitness: 66.41824255628177
# Min Fitness: 64.9118102154442
# -------------------------------------
# --------------- STATS ---------------
# Generation: 954
# Population Size: 60
# Mean Fitness: 66.18570483337368
# Std Fitness: 0.3061658968476877
# Max Fitness: 66.68493246187364
# Min Fitness: 65.24224449285887
# -------------------------------------
# --------------- STATS ---------------
# Generation: 955
# Population Size: 60
# Mean Fitness: 63.771071669490844
# Std Fitness: 0.2716634918186365
# Max Fitness: 64.19172887920601
# Min Fitness: 62.99847978697652
# -------------------------------------
# --------------- STATS ---------------
# Generation: 956
# Population Size: 60
# Mean Fitness: 64.13573262325507
# Std Fitness: 0.2656073296067563
# Max Fitness: 64.47042556281772
# Min Fitness: 63.29763447107238
# -------------------------------------
# --------------- STATS ---------------
# Generation: 957
# Population Size: 60
# Mean Fitness: 64.42339398047285
# Std Fitness: 0.20986376474695767
# Max Fitness: 64.66219317356573
# Min Fitness: 63.65054853546357
# -------------------------------------
# --------------- STATS ---------------
# Generation: 958
# Population Size: 60
# Mean Fitness: 62.97314393609296
# Std Fitness: 0.21641331645791967
# Max Fitness: 63.16112902444929
# Min Fitness: 62.49193318809005
# -------------------------------------
# --------------- STATS ---------------
# Generation: 959
# Population Size: 60
# Mean Fitness: 63.241884160413136
# Std Fitness: 0.13270622758235523
# Max Fitness: 63.38412975066569
# Min Fitness: 62.82808424110385
# -------------------------------------
# --------------- STATS ---------------
# Generation: 960
# Population Size: 60
# Mean Fitness: 62.92050983619786
# Std Fitness: 0.10800755633655888
# Max Fitness: 63.07039651416122
# Min Fitness: 62.60628419268942
# -------------------------------------
# --------------- STATS ---------------
# Generation: 961
# Population Size: 60
# Mean Fitness: 63.254239909626406
# Std Fitness: 0.09772101214699443
# Max Fitness: 63.31916920842411
# Min Fitness: 62.756322440087146
# -------------------------------------
# --------------- STATS ---------------
# Generation: 962
# Population Size: 60
# Mean Fitness: 63.3264781086097
# Std Fitness: 0.1293772058844207
# Max Fitness: 63.40628419268942
# Min Fitness: 62.682655047204065
# -------------------------------------
# --------------- STATS ---------------
# Generation: 963
# Population Size: 60
# Mean Fitness: 62.680180876301144
# Std Fitness: 0.047444007880513506
# Max Fitness: 62.74155022996853
# Min Fitness: 62.42818881626725
# -------------------------------------
# --------------- STATS ---------------
# Generation: 964
# Population Size: 60
# Mean Fitness: 61.60096364076496
# Std Fitness: 0.0724487406601703
# Max Fitness: 61.69120503510046
# Min Fitness: 61.340281771968044
# -------------------------------------
# --------------- STATS ---------------
# Generation: 965
# Population Size: 60
# Mean Fitness: 61.84835232792706
# Std Fitness: 0.09074859590346371
# Max Fitness: 62.03357637375938
# Min Fitness: 61.41174146695715
# -------------------------------------
# --------------- STATS ---------------
# Generation: 966
# Population Size: 60
# Mean Fitness: 61.53299753086421
# Std Fitness: 0.05972586821835371
# Max Fitness: 61.679941902687005
# Min Fitness: 61.42450738320019
# -------------------------------------
# --------------- STATS ---------------
# Generation: 967
# Population Size: 60
# Mean Fitness: 60.89309707092713
# Std Fitness: 0.07247720454064727
# Max Fitness: 61.05090292907286
# Min Fitness: 60.79599515855725
# -------------------------------------
# --------------- STATS ---------------
# Generation: 968
# Population Size: 60
# Mean Fitness: 60.88394687323489
# Std Fitness: 0.09427858996545903
# Max Fitness: 61.0325441781651
# Min Fitness: 60.75356862745098
# -------------------------------------
# --------------- STATS ---------------
# Generation: 969
# Population Size: 60
# Mean Fitness: 60.96446084079722
# Std Fitness: 0.10105383390984407
# Max Fitness: 61.11089034132171
# Min Fitness: 60.69071508109417
# -------------------------------------
# --------------- STATS ---------------
# Generation: 970
# Population Size: 60
# Mean Fitness: 61.03017445332041
# Std Fitness: 0.09423706713864964
# Max Fitness: 61.141178407165334
# Min Fitness: 60.90314209634471
# -------------------------------------
# --------------- STATS ---------------
# Generation: 971
# Population Size: 60
# Mean Fitness: 61.62340301783265
# Std Fitness: 0.09699314495692343
# Max Fitness: 61.743399661099005
# Min Fitness: 61.39036165577342
# -------------------------------------
# --------------- STATS ---------------
# Generation: 972
# Population Size: 60
# Mean Fitness: 62.19205202937142
# Std Fitness: 0.09151797823706538
# Max Fitness: 62.27442459452917
# Min Fitness: 62.0477908496732
# -------------------------------------
# --------------- STATS ---------------
# Generation: 973
# Population Size: 60
# Mean Fitness: 62.16728875978376
# Std Fitness: 0.08922975997455801
# Max Fitness: 62.27442459452917
# Min Fitness: 62.0477908496732
# -------------------------------------
# --------------- STATS ---------------
# Generation: 974
# Population Size: 60
# Mean Fitness: 61.842751230533366
# Std Fitness: 0.08920305254470318
# Max Fitness: 61.96433986928104
# Min Fitness: 61.73691600096829
# -------------------------------------
# --------------- STATS ---------------
# Generation: 975
# Population Size: 60
# Mean Fitness: 63.03294259662714
# Std Fitness: 0.094045022175732
# Max Fitness: 63.17032389251997
# Min Fitness: 62.88226192205278
# -------------------------------------
# --------------- STATS ---------------
# Generation: 976
# Population Size: 60
# Mean Fitness: 62.822505608004526
# Std Fitness: 0.10511789069647912
# Max Fitness: 63.001190994916485
# Min Fitness: 62.57354054708303
# -------------------------------------
# --------------- STATS ---------------
# Generation: 977
# Population Size: 60
# Mean Fitness: 62.64955933188091
# Std Fitness: 0.12649854461363122
# Max Fitness: 62.804620672960546
# Min Fitness: 62.337154199951584
# -------------------------------------
# --------------- STATS ---------------
# Generation: 978
# Population Size: 60
# Mean Fitness: 62.41832866941015
# Std Fitness: 0.11253075553269994
# Max Fitness: 62.54757492132656
# Min Fitness: 62.21422028564512
# -------------------------------------
# --------------- STATS ---------------
# Generation: 979
# Population Size: 60
# Mean Fitness: 62.47196204308884
# Std Fitness: 0.09518174107693082
# Max Fitness: 62.59401404018398
# Min Fitness: 62.31622367465505
# -------------------------------------
# --------------- STATS ---------------
# Generation: 980
# Population Size: 60
# Mean Fitness: 62.807070313886875
# Std Fitness: 0.11756969341678174
# Max Fitness: 62.971328976034854
# Min Fitness: 62.437523117889135
# -------------------------------------
# --------------- STATS ---------------
# Generation: 981
# Population Size: 60
# Mean Fitness: 61.86883395465182
# Std Fitness: 0.11374154092007654
# Max Fitness: 62.058542725732266
# Min Fitness: 61.58515032679738
# -------------------------------------
# --------------- STATS ---------------
# Generation: 982
# Population Size: 60
# Mean Fitness: 62.948555345759715
# Std Fitness: 0.12227359948879082
# Max Fitness: 63.120817235536194
# Min Fitness: 62.67625659646575
# -------------------------------------
# --------------- STATS ---------------
# Generation: 983
# Population Size: 60
# Mean Fitness: 63.00844722020495
# Std Fitness: 0.1186581416805535
# Max Fitness: 63.09368191721133
# Min Fitness: 62.517255870249336
# -------------------------------------
# --------------- STATS ---------------
# Generation: 984
# Population Size: 60
# Mean Fitness: 62.35276339869281
# Std Fitness: 0.12935053545929717
# Max Fitness: 62.471630113773905
# Min Fitness: 61.90978261922053
# -------------------------------------
# --------------- STATS ---------------
# Generation: 985
# Population Size: 60
# Mean Fitness: 62.236637973049305
# Std Fitness: 0.13606255924678748
# Max Fitness: 62.30492955700799
# Min Fitness: 61.482713144517064
# -------------------------------------
# --------------- STATS ---------------
# Generation: 986
# Population Size: 60
# Mean Fitness: 62.515488162672476
# Std Fitness: 0.16650111419706928
# Max Fitness: 62.61847688211087
# Min Fitness: 61.733918179617525
# -------------------------------------
# --------------- STATS ---------------
# Generation: 987
# Population Size: 60
# Mean Fitness: 62.59279825708061
# Std Fitness: 0.16453551670984667
# Max Fitness: 62.708380537400146
# Min Fitness: 61.84673541515372
# -------------------------------------
# --------------- STATS ---------------
# Generation: 988
# Population Size: 60
# Mean Fitness: 62.89967097555071
# Std Fitness: 0.16541027865191563
# Max Fitness: 63.03684725248124
# Min Fitness: 62.17373033163883
# -------------------------------------
# --------------- STATS ---------------
# Generation: 989
# Population Size: 60
# Mean Fitness: 63.588131751795366
# Std Fitness: 0.0936759274724198
# Max Fitness: 63.63955652384411
# Min Fitness: 63.01191963205035
# -------------------------------------
# --------------- STATS ---------------
# Generation: 990
# Population Size: 60
# Mean Fitness: 63.815657613168725
# Std Fitness: 0.0939031742761117
# Max Fitness: 63.8723640764948
# Min Fitness: 63.29427257322682
# -------------------------------------
# --------------- STATS ---------------
# Generation: 991
# Population Size: 60
# Mean Fitness: 63.98447588154603
# Std Fitness: 0.09988969903428645
# Max Fitness: 64.05417768094892
# Min Fitness: 63.423690147664004
# -------------------------------------
# --------------- STATS ---------------
# Generation: 992
# Population Size: 60
# Mean Fitness: 64.64736751391915
# Std Fitness: 0.06542540031960761
# Max Fitness: 64.69939869281046
# Min Fitness: 64.22749358508835
# -------------------------------------
# --------------- STATS ---------------
# Generation: 993
# Population Size: 60
# Mean Fitness: 65.77275713709354
# Std Fitness: 0.07792345929616781
# Max Fitness: 65.85488453159041
# Min Fitness: 65.35235052045509
# -------------------------------------
# --------------- STATS ---------------
# Generation: 994
# Population Size: 60
# Mean Fitness: 66.02650231582345
# Std Fitness: 0.07760461684115415
# Max Fitness: 66.11629145485355
# Min Fitness: 65.62032631324135
# -------------------------------------
# --------------- STATS ---------------
# Generation: 995
# Population Size: 60
# Mean Fitness: 65.82547063664973
# Std Fitness: 0.09215842435786623
# Max Fitness: 65.92598789639312
# Min Fitness: 65.42226095376422
# -------------------------------------
# --------------- STATS ---------------
# Generation: 996
# Population Size: 60
# Mean Fitness: 66.22519473896553
# Std Fitness: 0.1277835147135475
# Max Fitness: 66.40606535947713
# Min Fitness: 65.69292471556524
# -------------------------------------
# --------------- STATS ---------------
# Generation: 997
# Population Size: 60
# Mean Fitness: 65.87148086823206
# Std Fitness: 0.1304475619307342
# Max Fitness: 66.05676107480029
# Min Fitness: 65.42807843137254
# -------------------------------------
# --------------- STATS ---------------
# Generation: 998
# Population Size: 60
# Mean Fitness: 65.87991879286695
# Std Fitness: 0.14860636345981867
# Max Fitness: 66.11853013798111
# Min Fitness: 65.32563350278383
# -------------------------------------
# --------------- STATS ---------------
# Generation: 999
# Population Size: 60
# Mean Fitness: 66.05530231582344
# Std Fitness: 0.14278026664808824
# Max Fitness: 66.23079738562092
# Min Fitness: 65.43267973856209
# -------------------------------------
# --------------- STATS ---------------
# Generation: 1000
# Population Size: 60
# Mean Fitness: 65.99706660211409
# Std Fitness: 0.183225273469468
# Max Fitness: 66.24704914064391
# Min Fitness: 65.26543694020819
# -------------------------------------
